# %%
import numpy as np    # we're going to use numpy to process input and output data
import onnxruntime    # to inference ONNX models, we use the ONNX Runtime
import onnx
from onnx import numpy_helper
import urllib.request
import json
import time
import iree_onnx_ep as iree_ep

# display images in notebook
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont

# %matplotlib inline

# %%
# prepare progressbar
def show_progress(block_num, block_size, total_size):
    print("Downloaded: " + str(round(block_num * block_size / total_size *100,2)) + "%", end="\r")

import urllib.request

onnx_model_url = "https://huggingface.co/onnxmodelzoo/resnet50_Opset18_torch_hub/resolve/main/resnet50_Opset18_torch_hub.onnx"
imagenet_labels_url = "https://raw.githubusercontent.com/anishathalye/imagenet-simple-labels/master/imagenet-simple-labels.json"

# retrieve our model from the ONNX model zoo
urllib.request.urlretrieve(onnx_model_url, filename="model.onnx", reporthook=show_progress)
urllib.request.urlretrieve(imagenet_labels_url, filename="imagenet-simple-labels.json", reporthook=show_progress)
# Out:
# Downloaded: 115.31%
# ('imagenet-simple-labels.json', <http.client.HTTPMessage at 0x12122d7b0>)

# %%
import pathlib

# Register the EP plugin
onnxruntime.register_execution_provider_library(iree_ep.get_ep_name(), iree_ep.get_library_path())
print("EP plugin registered successfully")
# Out:
# EP plugin registered successfully

# %%
# Get IREE device
ep_devices = onnxruntime.get_ep_devices()
iree_device = None
for dev in ep_devices:
    print(dev.device.metadata)
# Out:
# {}
# {'iree.device_id': '0', 'iree.device_path': '', 'iree.driver': 'local-sync'}
# {'iree.device_id': '1', 'iree.device_path': '', 'iree.driver': 'local-task'}

# %%
# Get IREE device
ep_devices = onnxruntime.get_ep_devices()
iree_device = None
for dev in ep_devices:
    if dev.device.metadata.get('iree.driver') == "local-task":
        iree_device = dev
        break

if not iree_device:
    print("ERROR: IREE EP not found in EP devices")

print(f"IREE EP available (vendor={iree_device.ep_vendor})")
# Out:
# IREE EP available (vendor=IREE)

# %%
sess_options = onnxruntime.SessionOptions()
sess_options.log_severity_level = 1
provider_options = {
    "target_arch": "this-doesn't-need-to-be-specified",
    "opt_level": "O3",
    "save_intermediates": "1"
}
sess_options.add_provider_for_devices([iree_device], provider_options)

# Run the model on the backend
session = onnxruntime.InferenceSession('model.onnx', sess_options=sess_options)
# Out:
# 2026-02-04 20:33:16.200 Python[4136:36079] 2026-02-04 20:33:16.200963 [I:onnxruntime:, inference_session.cc:606 TraceSessionOptions] Session Options {  execution_mode:0 execution_order:DEFAULT enable_profiling:0 optimized_model_filepath:"" enable_mem_pattern:1 enable_mem_reuse:1 enable_cpu_mem_arena:1 profile_file_prefix:onnxruntime_profile_ session_logid: session_log_severity_level:1 session_log_verbosity_level:0 max_num_graph_transformation_steps:10 graph_optimization_level:4 intra_op_param:OrtThreadPoolParams { thread_pool_size: 0 auto_set_affinity: 0 allow_spinning: 1 dynamic_block_base_: 0 stack_size: 0 affinity_str:  set_denormal_as_zero: 0 } inter_op_param:OrtThreadPoolParams { thread_pool_size: 0 auto_set_affinity: 0 allow_spinning: 1 dynamic_block_base_: 0 stack_size: 0 affinity_str:  set_denormal_as_zero: 0 } use_per_session_threads:1 thread_pool_allow_spinning:1 use_deterministic_compute:0 ep_selection_policy:0 config_options: {   ep.iree.target_arch: this-doesn't-need-to-be-specified  ep.iree.save_intermediates: 1  ep.iree.opt_level: O3 } }
# 2026-02-04 20:33:16.201 Python[4136:36079] 2026-02-04 20:33:16.200995 [I:onnxruntime:, inference_session.cc:422 ConstructorCommon] Creating and using per session threadpools since use_per_session_threads_ is true
# 2026-02-04 20:33:16.201 Python[4136:36079] 2026-02-04 20:33:16.201005 [I:onnxruntime:, inference_session.cc:446 ConstructorCommon] Dynamic block base set to 0
# 2026-02-04 20:33:16.218 Python[4136:36079] 2026-02-04 20:33:16.218726 [I:onnxruntime:, inference_session.cc:2085 Initialize] Initializing session.
# 2026-02-04 20:33:16.218 Python[4136:36079] 2026-02-04 20:33:16.218761 [I:onnxruntime:, inference_session.cc:2123 Initialize] Adding default CPU execution provider.
# 2026-02-04 20:33:16.218 Python[4136:36079] 2026-02-04 20:33:16.218827 [I:onnxruntime:, graph_partitioner.cc:1220 InlineFunctionsAOT] This model does not have any local functions defined. AOT Inlining is not performed
# 2026-02-04 20:33:16.227 Python[4136:36079] 2026-02-04 20:33:16.227921 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer EnsureUniqueDQForNodeUnit modified: 0 with status: OK
# 2026-02-04 20:33:16.227 Python[4136:36079] 2026-02-04 20:33:16.227960 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer Level1_RuleBasedTransformer modified: 0 with status: OK
# 2026-02-04 20:33:16.227 Python[4136:36079] 2026-02-04 20:33:16.227973 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer DoubleQDQPairsRemover modified: 0 with status: OK
# 2026-02-04 20:33:16.227 Python[4136:36079] 2026-02-04 20:33:16.227991 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer ConstantSharing modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228057 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer CommonSubexpressionElimination modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228073 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer ConstantFolding modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228085 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MatMulAddFusion modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228098 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer ReshapeFusion modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228104 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer FreeDimensionOverrideTransformer modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228110 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer GeluFusionL1 modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228121 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer LayerNormFusionL1 modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228135 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer QDQPropagationTransformer modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228153 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer WeightBiasQuantization modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228165 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer EnsureUniqueDQForNodeUnit modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228177 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer WhereDummyDq modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228222 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer TransposeOptimizer modified: 0 with status: OK
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228791 [I:onnxruntime:, iree_ep.cc:150 CompileImpl] IREE EP: Saving MLIR to: /var/folders/ks/6c0sbzl52nn0dz016s77q5000000gn/T/iree_ep_1824008576295334070.mlir
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228799 [I:onnxruntime:, iree_ep.cc:153 CompileImpl] IREE EP: Saving VMFB to: /var/folders/ks/6c0sbzl52nn0dz016s77q5000000gn/T/iree_ep_17054491890399840094.vmfb
# 2026-02-04 20:33:16.228 Python[4136:36079] 2026-02-04 20:33:16.228804 [I:onnxruntime:, iree_ep.cc:160 CompileImpl] IREE EP: Generating MLIR
# 2026-02-04 20:33:17.088 Python[4136:36079] 2026-02-04 20:33:17.088153 [I:onnxruntime:, iree_ep.cc:163 CompileImpl] IREE EP: MLIR Generated Successfully
# 2026-02-04 20:33:17.088 Python[4136:36079] 2026-02-04 20:33:17.088194 [I:onnxruntime:, iree_ep.cc:168 CompileImpl] IREE EP: Generating VMFB
# 2026-02-04 20:33:19.241 Python[4136:36079] 2026-02-04 20:33:19.241500 [I:onnxruntime:, iree_ep.cc:172 CompileImpl] IREE EP: VMFB Generated Successfully
# 2026-02-04 20:33:19.241 Python[4136:36079] 2026-02-04 20:33:19.241554 [I:onnxruntime:, iree_ep.cc:176 CompileImpl] IREE EP: Creating runtime session
# 2026-02-04 20:33:19.241 Python[4136:36079] 2026-02-04 20:33:19.241567 [I:onnxruntime:, iree_ep.cc:187 CompileImpl] IREE EP: Loading VMFB module
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258493 [I:onnxruntime:, iree_ep.cc:198 CompileImpl] IREE EP: Looking up function
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258526 [I:onnxruntime:, iree_ep.cc:209 CompileImpl] IREE EP: Compilation complete
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258778 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_653'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258788 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_651'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258794 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_647'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258800 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_645'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258807 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_644'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258814 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_641'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258821 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_639'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258827 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_636'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258833 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_635'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258838 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_624'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258843 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_618'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258849 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_630'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258855 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_617'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258862 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_615'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258869 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_611'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258875 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_608'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258889 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_600'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258895 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_599'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258901 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_596'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258906 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_593'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258911 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_591'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258916 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_632'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258920 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_588'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258925 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_537'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258930 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_623'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258935 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_570'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258940 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_585'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258945 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_566'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258950 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_579'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258955 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_578'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258959 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_573'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258964 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_572'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258969 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_609'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258974 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_569'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258983 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_561'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258989 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'fc.bias'. It is no longer used by any node.
# 2026-02-04 20:33:19.258 Python[4136:36079] 2026-02-04 20:33:19.258995 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_560'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259000 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_627'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259005 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_558'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259009 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_614'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259014 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_584'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259019 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_581'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259024 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_620'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259028 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_557'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259033 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_552'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259038 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_654'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259043 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_543'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259048 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_551'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259052 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_549'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259057 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_564'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259064 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_540'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259070 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_546'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259076 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_542'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259088 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_536'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259096 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_594'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259102 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_509'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259107 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_518'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259111 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_534'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259116 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_605'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259121 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_597'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259125 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_563'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259130 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_575'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259135 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_648'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259139 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_554'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259144 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_602'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259149 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'fc.weight'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259154 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_576'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259159 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_531'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259164 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_506'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259168 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_513'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259173 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_533'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259177 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_498'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259188 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_528'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259194 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_512'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259199 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_612'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259204 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_590'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259209 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_539'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259213 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_501'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259218 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_606'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259223 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_567'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259227 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_642'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259232 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_525'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259237 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_527'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259242 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_522'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259247 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_507'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259252 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_633'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259256 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_519'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259262 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_582'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259267 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_500'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259272 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_516'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259277 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_515'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259283 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_555'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259289 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_638'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259294 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_650'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259298 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_521'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259303 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_587'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259308 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_503'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259313 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_497'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259317 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_548'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259322 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_504'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259327 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_629'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259331 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_545'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259336 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_524'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259341 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_621'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259345 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_603'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259350 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_626'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259355 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_510'. It is no longer used by any node.
# 2026-02-04 20:33:19.259 Python[4136:36079] 2026-02-04 20:33:19.259360 [I:onnxruntime:, graph.cc:5244 CleanUnusedInitializersAndNodeArgs] Removing initializer 'onnx::Conv_530'. It is no longer used by any node.
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261823 [I:onnxruntime:, inference_session.cc:1508 TransformGraph] Running graph optimizations in loop 1 time/s (Graph Optimizations Loop Level : 1)
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261833 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer Level2_RuleBasedTransformer modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261847 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer TransposeOptimizer_CPUExecutionProvider modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261855 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer QDQSelectorActionTransformer modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261862 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer GemmActivationFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261868 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MatMulIntegerToFloatFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261874 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer DynamicQuantizeMatMulFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261882 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer ConvActivationFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261890 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer GeluFusionL2 modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261898 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer LayerNormFusionL2 modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261906 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer SimplifiedLayerNormFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261914 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer AttentionFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261920 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer EmbedLayerNormFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261926 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer GatherSliceToSplitFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261932 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer GatherToSliceFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261937 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MatmulTransposeFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261943 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer BiasGeluFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261948 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer GroupQueryAttentionFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261954 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MatMulAddFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261960 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer SkipLayerNormFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261966 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer FastGeluFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261971 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer QuickGeluFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261977 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer BiasSoftmaxFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261982 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer BiasDropoutFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.261 Python[4136:36079] 2026-02-04 20:33:19.261993 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MatMulScaleFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.261998 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MatMulActivationFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262004 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MatMulNBitsFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262010 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer QDQFinalCleanupTransformer modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262016 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer NhwcTransformer modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262021 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer ConvAddActivationFusion modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262028 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer RemoveDuplicateCastTransformer modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262033 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer CastFloat16Transformer modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262039 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer FuseFp16InitializerToFp32NodeTransformer modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262049 [I:onnxruntime:, graph_transformer.cc:15 Apply] GraphTransformer MemcpyTransformer modified: 0 with status: OK
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262068 [I:onnxruntime:, allocation_planner.cc:2658 CreateGraphPartitioner] Use DeviceBasedPartition as default
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262088 [I:onnxruntime:, session_state_utils.cc:249 SaveInitializedTensors] Saving initialized tensors.
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262096 [I:onnxruntime:, session_state_utils.cc:445 SaveInitializedTensors] Done saving initialized tensors
# 2026-02-04 20:33:19.262 Python[4136:36079] 2026-02-04 20:33:19.262113 [I:onnxruntime:, inference_session.cc:2567 Initialize] Session successfully initialized.

# %%
def load_labels(path):
    with open(path) as f:
        data = json.load(f)
    return np.asarray(data)

def preprocess(input_data):
    # convert the input data into the float32 input
    img_data = input_data.astype('float32')

    #normalize
    mean_vec = np.array([0.485, 0.456, 0.406])
    stddev_vec = np.array([0.229, 0.224, 0.225])
    norm_img_data = np.zeros(img_data.shape).astype('float32')
    for i in range(img_data.shape[0]):
        norm_img_data[i,:,:] = (img_data[i,:,:]/255 - mean_vec[i]) / stddev_vec[i]
        
    #add batch channel
    norm_img_data = norm_img_data.reshape(1, 3, 224, 224).astype('float32')
    return norm_img_data

def prepare_image(image):
    return preprocess(np.array(image).transpose(2, 0, 1))

def softmax(x):
    x = x.reshape(-1)
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

def postprocess(result):
    return softmax(np.array(result)).tolist()

# %%
labels = load_labels('imagenet-simple-labels.json')
image0 = Image.open('images/dog.jpg')
image1 = Image.open('images/plane.jpg')

_, axarr = plt.subplots(2, 1)
axarr[0].axis("off")
axarr[0].imshow(image0)
axarr[1].axis("off")
axarr[1].imshow(image1)

input0 = prepare_image(image0)
input1 = prepare_image(image1)

# %%
def run_inference(inp, image):
    start = time.time()
    raw_result = session.run([], {"x": inp})
    end = time.time()
    res = postprocess(raw_result)

    inference_time = np.round((end - start) * 1000, 2)
    
    print('========================================')
    print('Inference time: ' + str(inference_time) + " ms")
    print('========================================')

    idx = np.argmax(res)

    print('========================================')
    print('Final top prediction is: ' + labels[idx])
    print('========================================')

    sort_idx = np.flip(np.squeeze(np.argsort(res)))
    print('============ Top 5 labels are: ============================')
    print(labels[sort_idx[:5]])
    print('===========================================================')
    
    plt.axis('off')
    display_image = plt.imshow(image)

# %%
run_inference(input0, image0)
# Out:
# 2026-02-04 20:33:29.239 Python[4136:36079] 2026-02-04 20:33:29.239222 [I:onnxruntime:, iree_ort_utils.cc:152 OrtTensorToIreeBufferView] IREE EP: Input tensor already on device, wrapping existing buffer (602112 bytes)
# ========================================
# Inference time: 1264.12 ms
# ========================================
# ========================================
# Final top prediction is: Golden Retriever
# ========================================
# ============ Top 5 labels are: ============================
# ['Golden Retriever' 'Labrador Retriever' 'Flat-Coated Retriever'
#  'Curly-coated Retriever' 'Norwich Terrier']
# ===========================================================
# 2026-02-04 20:33:30.499 Python[4136:36079] 2026-02-04 20:33:30.499323 [I:onnxruntime:, iree_ort_utils.cc:210 IreeBufferViewToOrtTensor] IREE EP: Output tensor on device, performing D2D copy (4000 bytes)

# %%
run_inference(input1, image1)
# Out:
# 2026-02-04 20:33:30.529 Python[4136:36079] 2026-02-04 20:33:30.529607 [I:onnxruntime:, iree_ort_utils.cc:152 OrtTensorToIreeBufferView] IREE EP: Input tensor already on device, wrapping existing buffer (602112 bytes)
# ========================================
# Inference time: 1529.0 ms
# ========================================
# ========================================
# Final top prediction is: airliner
# ========================================
# ============ Top 5 labels are: ============================
# ['airliner' 'military aircraft' 'wing' 'space shuttle' 'airship']
# ===========================================================
# 2026-02-04 20:33:32.058 Python[4136:36079] 2026-02-04 20:33:32.058402 [I:onnxruntime:, iree_ort_utils.cc:210 IreeBufferViewToOrtTensor] IREE EP: Output tensor on device, performing D2D copy (4000 bytes)
